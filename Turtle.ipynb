# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=8f23deedc4957c76e02171ba28f9a2339292d4899956e9f4b43810ba819bbda4
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %% [markdown]
# **Turtle**
#
# Similar to the virtual canvas that we can draw pictures and attractive shapes. It provides the onscreen pen that we can use for drawing

# %%
from ColabTurtle.Turtle import *

initializeTurtle()
bgcolor('orange')
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="orange"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
import ColabTurtle

dir(ColabTurtle)
# Out:
# ['Turtle',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
dir(ColabTurtle.Turtle)
# Out:
# ['DEFAULT_BACKGROUND_COLOR',
#  'DEFAULT_IS_PEN_DOWN',
#  'DEFAULT_PEN_COLOR',
#  'DEFAULT_PEN_WIDTH',
#  'DEFAULT_SPEED',
#  'DEFAULT_SVG_LINES_STRING',
#  'DEFAULT_TURTLE_DEGREE',
#  'DEFAULT_TURTLE_VISIBILITY',
#  'DEFAULT_WINDOW_SIZE',
#  'HTML',
#  'SPEED_TO_SEC_MAP',
#  'SVG_TEMPLATE',
#  'TURTLE_SVG_TEMPLATE',
#  'VALID_COLORS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_generateTurtleSvgDrawing',
#  '_genereateSvgDrawing',
#  '_moveToNewPosition',
#  '_speedToSec',
#  '_updateDrawing',
#  'background_color',
#  'backward',
#  'bgcolor',
#  'color',
#  'display',
#  'drawing_window',
#  'forward',
#  'goto',
#  'hideturtle',
#  'initializeTurtle',
#  'is_pen_down',
#  'is_turtle_visible',
#  'left',
#  'math',
#  'pen_color',
#  'pen_width',
#  'pendown',
#  'penup',
#  'right',
#  'setx',
#  'sety',
#  'showturtle',
#  'speed',
#  'svg_lines_string',
#  'time',
#  'timeout',
# ...

# %%
initializeTurtle(initial_speed=5)
color('orange')
bgcolor('grey')
for i in range(10):
  forward(100)
  left(150)
# for i in range(51):
#   forward(50)
#   left(150)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="grey"/>
# ...

# %%
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=8)
color('green')
bgcolor('white')
width(1)
for i in range(100):
    forward(100)
    left(70)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
# ...

# %%
initializeTurtle(initial_speed=10)
color('orange')
bgcolor('white')
width(1)
f = 0
for i in range(36):
    penup()
    setx(300)
    sety(300)
    for j in range(10):
      pendown()
      forward(10)
      left(5)
    right(40)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
# ...

# %%
initializeTurtle(initial_speed=10)
color('orange')
bgcolor('white')
width(1)
f = 0
for i in range(36):
    penup()
    setx(300)
    sety(300)
    for j in range(10):
      pendown()
      forward(10)
      left(5)
    right(40)
left(105)
for j in range(100):
  forward(6)
  left(3.6)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
# ...

# %%
initializeTurtle(initial_speed=10)
color('green')
bgcolor('white')
min_length=20

def draw_branch(l, w):
  left(15)
  draw_stick(l, w)
  right(30)
  draw_stick(l, w)
  left(15)

def draw_stick(l, w):
  width(w)
  forward(l)
  if min_length < l:
    draw_branch(math.ceil(l*0.8), math.ceil(w*0.6))
  backward(l)

penup()
sety(470)
pendown()
draw_branch(100, 10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
# ...
