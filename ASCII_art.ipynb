# %% [markdown]
# # **Req Installation**

# %%
pip install cowsay

# %%
import cowsay
cowsay.daemon("Hii Human, I'm Deamon")
# Out:
#   _____________________
# | Hii Human, I'm Deamon |
# ...
#                              \
#                               \
#                                \
#                                 \
#                                  /- _  `-/  '
#                                 (/\/ \ \   /\
#                                 / /   | `    \
#                                 O O   ) /    |
#                                 `-^--'`<     '
#                                (_.)  _  )   /
#                                 `.___/`    /
#                                   `-----' /
#                      <----.     __ / __   \
#                      <----|====O)))==) \) /====
#                      <----'    `--' `.__,' \
#                                   |        |
#                                    \       /
#                              ______( (_  / \______
#                            ,'  ,-----'   |        \
#                            `--{__________)        \/

# %%
cowsay.beavis("Can we play a game?")
# Out:
#   ___________________
# | Can we play a game? |
# ...
#                         \
#                          \
#                           \
#                                 _------~~-,
#                              ,'            ,
#                              /               \\
#                             /                :
#                            |                  '
#                            |                  |
#                            |                  |
#                             |   _--           |
#                             _| =-.     .-.   ||
#                             o|/o/       _.   |
#                             /  ~          \\ |
#                           (____\@)  ___~    |
#                              |_===~~~.`    |
#                           _______.--~     |
#                           \\________       |
#                                    \\      |
#                                  __/-___-- -__
# ...

# %%
print(cowsay.get_output_string('trex', 'Hello World,\n I am dinosaur'))
# Out:
#   _____________
#  /             \
# | Hello World,  |
# | I am dinosaur |
#  \             /
# ...
#                     \
#                      \
#                       \
#                        \
#                           .-=-==--==--.
#                     ..-=="  ,'o`)      `.
#                   ,'         `"'         \
#                  :  (                     `.__...._
#                  |                  )    /         `-=-.
#                  :       ,vv.-._   /    /               `---==-._
#                   \/\/\/VV ^ d88`;'    /                         `.
#                       ``  ^/d88P!'    /             ,              `._
#                          ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                         ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                        ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
# ...

# %%
print(cowsay.dragon("Hii, I'm Dragon. "))
# Out:
#   ________________
# | Hii, I'm Dragon. |
# ...
#                   \
#                    \
#                     \
#                      \
#                                            / \\  //\\
#                             |\\___/|      /   \\//  \\\\
#                             /0  0  \\__  /    //  | \\ \\
#                            /     /  \\/_/    //   |  \\  \\
#                            \@_^_\@'/   \\/_   //    |   \\   \\
#                            //_^_/     \\/_ //     |    \\    \\
#                         ( //) |        \\///      |     \\     \\
#                       ( / /) _|_ /   )  //       |      \\     _\\
#                     ( // /) '/,_ _ _/  ( ; -.    |    _ _\\.-~        .-~~~^-.
#                   (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#                  (( // / ))  '/\\      /                 ~-. _ .-~      .-~^-.  \\
#                  (( /// ))      `.   {            }                   /      \\  \\
# ...

# %%
cowsay.ghostbusters("I'm Ghost, I'm here to scare you!!")
# Out:
#   __________________________________
# | I'm Ghost, I'm here to scare you!! |
# ...
#                                           \
#                                            \
#                                             \
#                                              \
#                                                          __---__
#                                                       _-       /--______
#                                                  __--( /     \ )XXXXXXXXXXX\v.
#                                                .-XXX(   O   O  )XXXXXXXXXXXXXXX-
#                                               /XXX(       U     )        XXXXXXX\
#                                             /XXXXX(              )--_  XXXXXXXXXXX\
#                                            /XXXXX/ (      O     )   XXXXXX   \XXXXX\
#                                            XXXXX/   /            XXXXXX   \__ \XXXXX
# ...

# %%
characters = cowsay.ch_name()

print("Available characters:", characters)
# print(", ".join(characters))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3b6bd7393d84> in <cell line: 1>()
# ----> 1 characters = cowsay.ch_name()
#       2
#       3 print("Available characters:", characters)
#       4 # print(", ".join(characters))
#
# TypeError: 'str' object is not callable

# %%
dir(cowsay)
# Out:
# ['CHARS',
#  'CowsayError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'beavis',
#  'ch_lines',
#  'ch_name',
#  'char_funcs',
#  'char_names',
#  'characters',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'draw',
#  'fox',
#  'func',
#  'get_output_string',
#  'ghostbusters',
#  'kitty',
#  'main',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
characters = ['beavis', 'cheese', 'cow', 'daemon', 'dragon', 'fox', 'ghostbusters', 'kitty', 'meow', 'miki', 'milk', 'octopus', 'pig', 'stegosaurus', 'stimpy', 'trex', 'turkey', 'turtle', 'tux']

message = "Hello from cowsay!"

for character in characters:
  print(f"\n{character.capitalize()} says:")
  if hasattr(cowsay, character):
    getattr(cowsay, character)(message)
# Out:
# Beavis says:
#   __________________
# | Hello from cowsay! |
# ...
#                        \
#                         \
#                          \
#                                _------~~-,
#                             ,'            ,
#                             /               \\
#                            /                :
#                           |                  '
#                           |                  |
#                           |                  |
#                            |   _--           |
#                            _| =-.     .-.   ||
#                            o|/o/       _.   |
#                            /  ~          \\ |
#                          (____\@)  ___~    |
#                             |_===~~~.`    |
#                          _______.--~     |
#                          \\________       |
#                                   \\      |
#                                 __/-___-- -__
# ...
